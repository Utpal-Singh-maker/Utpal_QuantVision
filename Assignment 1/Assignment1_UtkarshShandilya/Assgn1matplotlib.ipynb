# %% [markdown]
# **NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP.**
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Import matplotlib.pyplot as plt**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Exercise 1
#
# **Follow along with these steps**
# * Create a figure object called fig using plt.figure()
# * Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
# * Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
fig1=plt.figure()
x = np.arange(0,100)
y = x*2
axes=fig1.add_axes([0,0,1,1])
axes.plot(x,y,color='red')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Asgn1")
plt.show()

# %% [markdown]
# ## Exercise 2
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig2=plt.figure()
x = np.arange(0,100)
y = x*2
axes=fig2.add_axes([0,0,1,1])
axes2=fig2.add_axes([0.2,0.5,.2,.2])

plt.show()

# %% [markdown]
# **Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig2=plt.figure()
x = np.arange(0,100)
y = x*2
axes=fig2.add_axes([0,0,1,1])
axes2=fig2.add_axes([0.2,0.5,.2,.2])
axes.plot(x,y,color='red')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Asgn1")
axes2.plot(x,y,color='blue')
plt.xlabel("x-axis-inner")
plt.ylabel("y-axis-inner")
plt.title("Asgn1-inner")
plt.show()

# %% [markdown]
# ## Exercise 3
#
# **Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig3=plt.figure()
x = np.arange(0,100)
y = x*2
axes=fig3.add_axes([0,0,1,1])
axes2=fig3.add_axes([0.2,0.5,.2,.2])

plt.show()

# %% [markdown]
# **Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig3=plt.figure()
x = np.arange(0,100)
y = x
axes1=fig3.add_axes([0,0,1,1])
axes2=fig3.add_axes([0.2,0.5,.2,.2])
axes1.plot(x,y**2,color='red')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Asgn1")
axes2.plot(x,y*2,color='blue')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
axes2.set_ylim(30,50)
axes2.set_xlim(20,22)
axes1.set_ylim(0,10000)
axes1.set_xlim(0,100)
plt.title("Zoomed")
# Out:
# Text(0.5, 1.0, 'Zoomed')

# %% [markdown]
# ## Exercise 4
#
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()
x = np.arange(0,1,0.2)
y = x
plt.subplot(1,2,1)

x = np.arange(0,1,0.2)
y = x
plt.subplot(1,2,2)


plt.show()

# %% [markdown]
# **Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
x = np.arange(0,100)
y = x*2
plt.figure()
plt.subplot(1,2,1)
plt.plot(x,y,linestyle='dashed',color='blue')


z = x**2
plt.subplot(1,2,2)
plt.plot(x,z,color='red')

plt.show()

# %% [markdown]
# **See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
x = np.arange(0,100)
y = x*2
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
plt.plot(x,y,color='blue',linewidth='4')


z = x**2
plt.subplot(1,2,2)
plt.plot(x,z,color='red',linestyle='dashed',linewidth='4')

plt.show()

# %% [markdown]
# # Great Job!
